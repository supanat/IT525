# %%
import os
import pandas as np
import pandas as pd
import matplotlib.pyplot as plt 
# %matplotlib inline


import statsmodels.formula.api as smf

# %%
path = '/Users/supanat/Dev/DS/Lab05'
path
# Out:
# '/Users/supanat/Dev/DS/Lab05'

# %%
df = pd.read_excel('Home Market Value.xlsx', sheetname='Data', skiprows=2) 
df.columns
# Out:
# Index(['House Age', 'Square Feet', 'Market Value'], dtype='object')

# %%
df
# Out:
#     House Age  Square Feet  Market Value
# 0          33         1812         90000
# 1          32         1914        104400
# 2          32         1842         93300
# 3          33         1812         91000
# 4          32         1836        101900
# 5          33         2028        108500
# 6          32         1732         87600
# 7          33         1850         96000
# 8          32         1791         89200
# 9          33         1666         88400
# 10         32         1852        100800
# 11         32         1620         96700
# 12         32         1692         87500
# 13         32         2372        114000
# 14         32         2372        113200
# 15         33         1666         87500
# 16         32         2123        116100
# 17         32         1620         94700
# 18         32         1731         86400
# 19         32         1666         87100
# 20         28         1520         83400
# 21         27         1484         79800
# ...

# %%
X = df['Square Feet']
y = df['Market Value']

# %%
fig,ax = plt.subplots()
ax.scatter(X,y,facecolor='pink',edgecolor='red')
#ax.set_xlim(1500)
ax.set_xlabel('Square Feet')
plt.ylabel('Market Value')
ax.set_title('Scatter Plot')

fig.savefig('scatter_plot.jpg')

# %%
model = smf.ols(formula='y~X', data=df).fit()  # ols : dodinary ~lease squafre error ,y ตัวแปรตาม x ตัวแปรอิสระ
model.params
# Out:
# Intercept    32673.219897
# X               35.036373
# dtype: float64

# %%
predicted_Y = model.predict(X)

# %%
predicted_Y
# Out:
# 0      96159.127018
# 1      99732.837022
# 2      97210.218196
# 3      96159.127018
# 4      96999.999960
# 5     103726.983497
# 6      93356.217212
# 7      97490.509177
# 8      95423.363194
# 9      91043.816621
# 10     97560.581922
# 11     89432.143482
# 12     91954.762308
# 13    115779.495665
# 14    115779.495665
# 15     91043.816621
# 16    107055.438892
# 17     89432.143482
# 18     93321.180839
# 19     91043.816621
# 20     85928.506224
# 21     84667.196811
# 22     88310.979560
# 23     88661.343286
# 24     84667.196811
# 25     84667.196811
# 26     85928.506224
# 27     92270.089662
# 28     84667.196811
# 29     84106.614850
# 30     85928.506224
# 31     85928.506224
# 32     84667.196811
# 33     85928.506224
# 34     91113.889366
# 35     88310.979560
# 36     95178.108586
# 37     84667.196811
# 38     85928.506224
# 39     85928.506224
# 40     91674.471328
# 41     88065.724952
# dtype: float64

# %%
fig,ax = plt.subplots()
ax.scatter(X,y,facecolor='pink',edgecolor='red')
plt.plot(X,predicted_Y,color='red')
ax.set_xlabel('Square Feet')
plt.ylabel('Market Value')
ax.set_title('Scatter Plot')

fig.savefig('scatter_plot.jpg')

# %%
model.rsquared
# Out:
# 0.53473420167449226

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.535
# Model:                            OLS   Adj. R-squared:                  0.523
# Method:                 Least Squares   F-statistic:                     45.97
# Date:                Sat, 10 Feb 2018   Prob (F-statistic):           3.80e-08
# Time:                        18:06:32   Log-Likelihood:                -432.12
# No. Observations:                  42   AIC:                             868.2
# Df Residuals:                      40   BIC:                             871.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   3.267e+04   8831.951      3.699      0.001    1.48e+04    5.05e+04
# ...

# %% [markdown]
# ดู rsqaure และ. pvalue (>0.05)

# %% [markdown]
# ### Multiple Linear Regressino

# %%
df = pd.read_excel('Colleges and Universities.xlsx', sheetname='Data', skiprows=2) 
df.columns
# Out:
# Index(['School', 'Type', 'Median SAT', 'Acceptance Rate',
#        'Expenditures/Student', 'Top 10% HS', 'Graduation %'],
#       dtype='object')

# %%
X = df[['Median SAT', 'Acceptance Rate', 'Expenditures/Student', 'Top 10% HS']]
y = df['Graduation %']

# %%
from sklearn import linear_model

# %%
lm = linear_model.LinearRegression()

# %%
model = lm.fit(X, y)

# %%
model.coef_
# Out:
# array([  7.20062848e-02,  -2.48592318e+01,  -1.35649860e-04,
#         -1.62764489e-01])

# %%
model.intercept_
# Out:
# 17.920955870559311

# %%
predicted_Y = model.predict(X)

# %%
residuals = predicted_Y - y

# %%
fig,axes  = plt.subplots(2,2)

axes[0,0].scatter(df['Median SAT'],residuals,facecolor='pink',edgecolor='red')
axes[0,0].set_xlim(0,1500)
axes[0,0].set_ylim(-20,20)
axes[0,0].set_xlabel('Median SAT')
axes[0,0].set_ylabel('Residual')
axes[0,0].plot([0,1500],[0,0],color='red',linewidth=1,linestyle='--')


axes[0, 1].scatter(df['Top 10% HS'], residuals, facecolor='skyblue', edgecolor='blue')
axes[0, 1].set_xlabel('Top 10% HS')
axes[0, 1].set_ylabel('Residuals')
axes[0, 1].set_xlim(0, 120)
axes[0, 1].set_ylim(-20, 20)
axes[0, 1].plot([0, 120], [0, 0], color='blue', linestyle='--', linewidth=1)


axes[1, 0].scatter(df['Acceptance Rate']*100, residuals, facecolor='lightgreen', edgecolor='green') 
axes[1, 0].set_xlabel('Acceptance Rate')
axes[1, 0].set_ylabel('Residuals')
axes[1, 0].set_xlim(0, 80)
axes[1, 0].set_ylim(-50, 50)
axes[1, 0].plot([0, 80], [0, 0], color='green', linestyle='--', linewidth=1)


axes[1, 1].scatter(df['Expenditures/Student'], residuals, facecolor='gray', edgecolor='black') 
axes[1, 1].set_xlabel('Expenditures/Student')
axes[1, 1].set_ylabel('Residuals')
axes[1, 1].set_xlim(0, 120000)
axes[1, 1].set_ylim(-50, 50)
axes[1, 1].plot([0, 120000], [0, 0], color='black', linestyle='--', linewidth=1)


fig.tight_layout()

# %% [markdown]
# ### Multiples Linear Regression

# %%
df = pd.read_excel('Banking Data.xlsx', sheetname='Data', skiprows=3)
df.columns
X = df[['Age', 'Education', 'Income', 'Home Value', 'Wealth']]
y = df[['Balance']]

# %%
df.columns
# Out:
# Index(['Age', 'Education', 'Income', 'Home Value', 'Wealth', 'Balance'], dtype='object')

# %%
model = smf.ols(formula='y~X', data=df).fit()

# %%
model.params
# Out:
# Intercept   -10710.642783
# X[0]           318.664963
# X[1]           621.860347
# X[2]             0.146323
# X[3]             0.009183
# X[4]             0.074332
# dtype: float64

# %%
model.summary()
# p valueควรต่ำกว่า0.05
# ดู Adj. R-squared  ใกล้ 1 ดี
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.947
# Model:                            OLS   Adj. R-squared:                  0.944
# Method:                 Least Squares   F-statistic:                     342.4
# Date:                Sat, 10 Feb 2018   Prob (F-statistic):           1.52e-59
# Time:                        18:44:20   Log-Likelihood:                -919.73
# No. Observations:                 102   AIC:                             1851.
# Df Residuals:                      96   BIC:                             1867.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -1.071e+04   4260.976     -2.514      0.014   -1.92e+04   -2252.672
# ...

# %% [markdown]
#  X[1] 0.054 ตัดออกได้

# %% [markdown]
# ลองเอา HomeValueออก

# %%
X = df[['Age', 'Education', 'Income', 'Wealth']]

# %%
model = smf.ols(formula='y~X', data=df).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.947
# Model:                            OLS   Adj. R-squared:                  0.944
# Method:                 Least Squares   F-statistic:                     429.2
# Date:                Sat, 10 Feb 2018   Prob (F-statistic):           9.69e-61
# Time:                        18:47:17   Log-Likelihood:                -920.10
# No. Observations:                 102   AIC:                             1850.
# Df Residuals:                      97   BIC:                             1863.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -1.243e+04   3718.674     -3.343      0.001   -1.98e+04   -5051.918
# ...

# %%
df['Education'].corr

# %%
Indx = df[['Age', 'Education', 'Income', 'Home Value', 'Wealth']]

# %%
Indx.corr()
# Out:
#                  Age  Education    Income  Home Value    Wealth
# Age         1.000000   0.173407  0.477147    0.386493  0.468092
# Education   0.173407   1.000000  0.575394    0.753521  0.469413
# Income      0.477147   0.575394  1.000000    0.795355  0.946665
# Home Value  0.386493   0.753521  0.795355    1.000000  0.698478
# Wealth      0.468092   0.469413  0.946665    0.698478  1.000000

# %%
df.corr(method='pearson')
# Out:
#                  Age  Education    Income  Home Value    Wealth   Balance
# Age         1.000000   0.173407  0.477147    0.386493  0.468092  0.565467
# Education   0.173407   1.000000  0.575394    0.753521  0.469413  0.554881
# Income      0.477147   0.575394  1.000000    0.795355  0.946665  0.951684
# Home Value  0.386493   0.753521  0.795355    1.000000  0.698478  0.766387
# Wealth      0.468092   0.469413  0.946665    0.698478  1.000000  0.948712
# Balance     0.565467   0.554881  0.951684    0.766387  0.948712  1.000000

# %% [markdown]
# กรณี ไม่เป็นตัวเลข  เป็น catagoercal

# %%
df = pd.read_excel('Employee Salaries.xlsx', sheetname='Data', skiprows=2)
df.columns
#X = df[['Age', 'Education', 'Income', 'Home Value', 'Wealth']]
#y = df[['Balance']]
# Out:
# Index(['Employee', 'Salary', 'Age', 'MBA'], dtype='object')

# %%
df.head()
# MBA ไม่เป็นตัวเลข
# Out:
#    Employee  Salary  Age  MBA
# 0         1   28260   25   No
# 1         2   43392   28  Yes
# 2         3   56322   37  Yes
# 3         4   26086   23   No
# 4         5   36807   32   No

# %%
df['MBA'].replace(['Yes','No'],[1,0],inplace=True)

# %%
df
# Out:
#     Employee  Salary  Age  MBA
# 0          1   28260   25    0
# 1          2   43392   28    1
# 2          3   56322   37    1
# 3          4   26086   23    0
# 4          5   36807   32    0
# 5          6   57119   57    0
# 6          7   48907   45    0
# 7          8   34301   32    0
# 8          9   31104   25    0
# 9         10   60054   57    0
# 10        11   41420   42    0
# 11        12   36508   25    1
# 12        13   40015   38    0
# 13        14   48329   47    0
# 14        15   39849   38    0
# 15        16   31985   31    0
# 16        17   59160   54    0
# 17        18   60335   59    0
# 18        19   35911   32    0
# 19        20   57814   55    0
# 20        21   42377   36    0
# 21        22   62430   60    0
# 22        23   46928   49    0
# 23        24   34403   35    0
# 24        25   45714   32    1
# 25        26   42247   27    1
# 26        27   54789   52    0
# 27        28   31702   30    0
# 28        29   34406   33    0
# ...

# %%
X2 = df[['Age','MBA']]
y = df['Salary']

# %%
model = smf.ols(formula='y~X2', data=df).fit()

# %%
model.params
# Out:
# Intercept      893.587597
# X2[0]         1044.146043
# X2[1]        14767.231588
# dtype: float64

# %% [markdown]
# salary = 893.587597 + 1044.146043 x Age + 14767.231588 x MBA

# %%
model.rsquared_adj
# Out:
# 0.94985773337557133

# %%
df.corr(method='pearson')
# Out:
#           Employee    Salary       Age       MBA
# Employee  1.000000  0.226830  0.238448 -0.075063
# Salary    0.226830  1.000000  0.881370  0.217773
# Age       0.238448  0.881370  1.000000 -0.217502
# MBA      -0.075063  0.217773 -0.217502  1.000000

# %% [markdown]
# In Case more level of Categorical

# %%
df = pd.read_excel('Surface Finish.xlsx', sheetname='Data', skiprows=2)

# %%
df
# Out:
#     Part  Surface Finish  RPM Cutting Tool
# 0      1           45.44  225            A
# 1      2           42.03  200            A
# 2      3           50.10  250            A
# 3      4           48.75  245            A
# 4      5           47.92  235            A
# 5      6           47.79  237            A
# 6      7           52.26  265            A
# 7      8           50.52  259            A
# 8      9           45.58  221            A
# 9     10           44.78  218            A
# 10    11           33.50  224            B
# 11    12           31.23  212            B
# 12    13           37.52  248            B
# 13    14           37.13  260            B
# 14    15           34.70  243            B
# 15    16           33.92  238            B
# 16    17           32.13  224            B
# 17    18           35.47  251            B
# 18    19           33.49  232            B
# 19    20           32.29  216            B
# 20    21           27.44  225            C
# ...

# %%
# surface finish = b0+b1*rpm+b2*cutting_tool 


# surface finish = b0+b1*rpm+b2*toolA + b3*toolC + b4*toolD

# %%
import numpy as np
df['A'] =0
df['B'] = np.where(df['Cutting Tool']=='B',1,0)
df['C'] = np.where(df['Cutting Tool']=='C',1,0)
df['D'] = np.where(df['Cutting Tool']=='D',1,0)

# %%
df
# Out:
#     Part  Surface Finish  RPM Cutting Tool  A  B  C  D
# 0      1           45.44  225            A  0  0  0  0
# 1      2           42.03  200            A  0  0  0  0
# 2      3           50.10  250            A  0  0  0  0
# 3      4           48.75  245            A  0  0  0  0
# 4      5           47.92  235            A  0  0  0  0
# 5      6           47.79  237            A  0  0  0  0
# 6      7           52.26  265            A  0  0  0  0
# 7      8           50.52  259            A  0  0  0  0
# 8      9           45.58  221            A  0  0  0  0
# 9     10           44.78  218            A  0  0  0  0
# 10    11           33.50  224            B  0  1  0  0
# 11    12           31.23  212            B  0  1  0  0
# 12    13           37.52  248            B  0  1  0  0
# 13    14           37.13  260            B  0  1  0  0
# 14    15           34.70  243            B  0  1  0  0
# 15    16           33.92  238            B  0  1  0  0
# ...

# %%
X3 = df[['RPM','B','C','D']]
y = df['Surface Finish']

# %%
model = smf.ols(formula='y~X3', data=df).fit()

# %%
model.params
# Out:
# Intercept    24.494372
# X3[0]         0.097761
# X3[1]       -13.310568
# X3[2]       -20.487000
# X3[3]       -26.036745
# dtype: float64

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.989
# Model:                            OLS   Adj. R-squared:                  0.987
# Method:                 Least Squares   F-statistic:                     669.7
# Date:                Sat, 10 Feb 2018   Prob (F-statistic):           7.32e-29
# Time:                        19:20:20   Log-Likelihood:                -49.955
# No. Observations:                  35   AIC:                             109.9
# Df Residuals:                      30   BIC:                             117.7
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     24.4944      2.473      9.904      0.000      19.443      29.546
# ...

# %%
model = smf.ols(formula='y~X3-1', data=df).fit() # formulaจะไม่ estimate intercep ให้
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.997
# Model:                            OLS   Adj. R-squared:                  0.996
# Method:                 Least Squares   F-statistic:                     2238.
# Date:                Sat, 10 Feb 2018   Prob (F-statistic):           1.13e-37
# Time:                        19:22:43   Log-Likelihood:                -75.355
# No. Observations:                  35   AIC:                             158.7
# Df Residuals:                      31   BIC:                             164.9
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# X3[0]          0.1998      0.003     67.856      0.000       0.194       0.206
# ...
