# %% [markdown]
# ### Homework-01

# %% [markdown]
# Supanat Jintawatsakoon<br>supanat.jtk@g.swu.ac.th

# %% [markdown]
# ### 2. Data Wrangling and Pre-processing

# %% [markdown]
# 2.1 ทําการอิมพอร์ตเพ็กเก็จและกําหนดค่าต่างๆที่จําเป็น

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
from matplotlib import cm
from collections import OrderedDict
# %matplotlib inline

# %%
cmaps = OrderedDict()

# %% [markdown]
# 2.2 เปลี่ยนไดเร็กทอรี่ไปที่ไดเร็กทอรี่ที่มีไฟล์ชุดข้อมูลอยู่และทําการอ่านไฟล์ชุดข้อมูลไปเก็บไว้ในตัวแปรชื่อ df

# %%
path = os.getcwd()
path += "/dataset/"
fileName = "hw01_burger_king_nutrition_fact_sheet.csv";
fullPath = path+fileName
fullPath
# Out:
# '/Users/supanat/Dev/DS/IT525/Projects/it525_2_2017_hw01/dataset/hw01_burger_king_nutrition_fact_sheet.csv'

# %%
df = pd.read_csv(fullPath)
df.head()
# Out:
#                  Nutrition facts  serving size (g)   Calories  \
# 0            WHOPPER® Sandwiches               NaN        NaN
# 1              WHOPPER® Sandwich               270      660.0
# 2                       w/o Mayo               249      500.0
# 3  WHOPPER® Sandwich with Cheese               292      740.0
# 4                       w/o Mayo               271      580.0
#
#     Calories from fat   Total fat (g)   Saturated Fat (g)   Trans Fat (g)  \
# 0                 NaN             NaN                 NaN             NaN
# 1               360.0            40.0                12.0             1.5
# 2               200.0            22.0                 9.0             1.5
# 3               420.0            46.0                16.0             2.0
# 4               260.0            29.0                13.0             1.5
#
#     Chol (mg)   Sodium (mg)  Total Carb (g)   Dietary Fiber (g)  \
# 0         NaN           NaN             NaN                 NaN
# 1        90.0         980.0              49                 2.0
# 2        80.0         840.0              49                 2.0
# 3       115.0        1340.0              50                 2.0
# 4       105.0        1200.0              50                 2.0
#
#     Total Sugar (g)   Protein (g)
# 0               NaN           NaN
# 1              11.0          28.0
# 2              11.0          28.0
# 3              11.0          32.0
# 4              11.0          32.0

# %% [markdown]
# 2.3 แสดงจํานวนแถวและจํานวนคอลัมน์ของชุดข้อมูล

# %%
rowsCount = df.shape[0]
columsCount = df.shape[1]
print ("rows x colums")
print(df.shape)
print("rows count : ", rowsCount)
print("columns count : ", columsCount)
# Out:
# rows x colums
# (210, 13)
# rows count :  210
# columns count :  13

# %% [markdown]
# 2.4 แสดงรายชื่อคอลัมน์ที่มีอยู่ในชุดข้อมูล

# %%
df.columns
# Out:
# Index(['Nutrition facts', ' serving size (g)', ' Calories',
#        ' Calories from fat', ' Total fat (g)', ' Saturated Fat (g)',
#        ' Trans Fat (g)', ' Chol (mg)', ' Sodium (mg)', ' Total Carb (g)',
#        ' Dietary Fiber (g)', ' Total Sugar (g)', ' Protein (g)'],
#       dtype='object')

# %% [markdown]
# 2.5 ทําการลบช่องว่างที่อยู่หน้าชื่อคอลัมน์ออก เพื่อว่าเวลาอ้างถึงชื่อคอลัมน์จะได้ใช้ชื่อตรงๆได้เลยไม่ต้องพิมพ์ช่องว่าง

# %%
df.columns = map(lambda x: x.strip(), df.columns.values)

# %%
df.columns
# Out:
# Index(['Nutrition facts', 'serving size (g)', 'Calories', 'Calories from fat',
#        'Total fat (g)', 'Saturated Fat (g)', 'Trans Fat (g)', 'Chol (mg)',
#        'Sodium (mg)', 'Total Carb (g)', 'Dietary Fiber (g)', 'Total Sugar (g)',
#        'Protein (g)'],
#       dtype='object')

# %% [markdown]
# 2.6 นับจํานวนอาหารในชนิด burger, sandwich, salad, และ beverage พร้อมทั้งแสดงภาพโดยใช้ bar graph และ pie chart

# %% [markdown]
# - นับจํานวนอาหารที่มีอยู่ในแต่ละชนิดที่เป็นburger,sandwich,salad,และbeverage

# %%
mydict = dict()
mydict['burger'] = len(df[df['Nutrition facts'].str.contains('burger|Burger')])
mydict['sandwich'] = len(df[df['Nutrition facts'].str.contains('Sandwich|Sandwiches')])
mydict['salad'] = len(df[df['Nutrition facts'].str.contains('Salad|salad')])
mydict['beverage'] = len(df[df['Nutrition facts'].str.contains('Milk|Juice|Shake|Smoothie|Tea|Lemonade|Coke|Coca Cola|Orange|Punch|Sprite|Beer|Pepper')])

# %%
mydict.keys
# Out:
# <function dict.keys>

# %% [markdown]
# - สร้าง bar graph และ pie chart เพื่อแสดงสัดส่วนจํานวนอาหารที่มีอยู่ในแต่ละชนิด โดยให้กราฟทั้ง สองอยู่ใน figure เดียวกัน แต่คนละ subplots

# %%
mydict.values()
# Out:
# dict_values([13, 14, 6, 26])

# %%
cmaps['Set1'] = ['Pink', 'yellowgreen', 'lightskyblue', 'Gold',]

# %%
fig,axPlots = plt.subplots(1,2)
axPlots[0].bar(mydict.keys(), mydict.values(), width=0.5, align='center', color=cmaps['Set1']) 
axPlots[0].set_xlabel('Category')
axPlots[0].set_ylabel('Amount')
#axPlots[0].set_aspect(1)
axPlots[1].pie(mydict.values(), labels=mydict.keys(), autopct='%1.1f%%', startangle=0, shadow=True, colors=cmaps['Set1']) 
axPlots[1].legend( loc="lower left",fontsize=6)
#axPlots[1].set_aspect(1)
plt.axis('equal')
plt.title('The Amount of Snack Food Consuption')
#plt.subplots_adjust(left=0.0, bottom=0.5, right=0.45)
fig.tight_layout()
fig.autofmt_xdate()

# %% [markdown]
# 2.7 ทําการแทนค่าข้อมูลใน cell ที่มีแต่ช่องว่าง (whitespace) อย่างเดียวด้วย NaN —เนื่องจากข้อมูลในชุดข้อมูลอาจมี ข้อมูลที่เป็นช่องว่าง (whitespace) อย่างเดียว อยู่ โดยอาจจะเป็นความตั้งใจหรือความผิดพลาดของการป้อนข้อมูล หรือสร้างชุดข้อมูลขึ้นมา ซึ่งทําให้โปรแกรมคิดว่ามันเป็นข้อมูลชนิดหนึ่ง ไม่ใช้ข้อมูลที่ขาดหาย (missing value)

# %%
len(df[df.isnull().any(axis=1)])
# Out:
# 28

# %%
# คอลัมน์ที่มี ช่องว่าง
df.isnull().any(axis=0)
# Out:
# Nutrition facts      False
# serving size (g)      True
# Calories              True
# Calories from fat     True
# Total fat (g)         True
# Saturated Fat (g)     True
# Trans Fat (g)         True
# Chol (mg)             True
# Sodium (mg)           True
# Total Carb (g)        True
# Dietary Fiber (g)     True
# Total Sugar (g)       True
# Protein (g)           True
# dtype: bool

# %%
# แถวที่มี ช่องว่าง
df.isnull().any(axis=1)
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12      True
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24      True
# 25     False
# 26     False
# 27      True
# 28     False
# 29     False
#        ...
# 180    False
# 181    False
# 182    False
# 183    False
# 184     True
# 185    False
# 186    False
# 187    False
# 188    False
# 189     True
# 190    False
# 191    False
# 192    False
# 193     True
# 194    False
# 195    False
# 196    False
# 197    False
# 198    False
# 199     True
# 200    False
# 201    False
# 202    False
# 203    False
# 204     True
# 205    False
# 206    False
# 207    False
# 208    False
# 209    False
# Length: 210, dtype: bool

# %% [markdown]
# - แทนค่าข้อมูลที่เป็นช่องว่างอย่างเดียวด้วยNaNเช่นในไฟลNcsvแทนที่,'',ด้วย,NaN,

# %%
df.replace(r'^\s*$', np.nan, regex=True, inplace=True)

# %%
len(df[df.isnull().any(axis=1)])
# Out:
# 94

# %% [markdown]
# 2.8 ลบแถวข้อมูลที่มีค่าNaNอยู่ไม่ว่าจะมีแค่คอลัมน์เดียวหรือทุกคอลัมน์ในแถวข้อมูลนั้นๆ

# %% [markdown]
# - แสดงลิสต์ของ row indices ที่มีค่า NaN

# %%
r_index = df[df.isnull().any(axis=1)].index.tolist()
#r_index

# %% [markdown]
# - แสดงจํานวนแถวข้อมูลที่มีค่า NaN อยู่ ซึ่งควรมี 94 แถว

# %%
len(r_index)
# Out:
# 94

# %% [markdown]
# - ทําการลบแถวข้อมูลที่มีค่าNaNอยู่

# %%
df.drop(r_index,inplace=True)

# %% [markdown]
# - ตรวจสอบจํานวนแถวของชุดข้อมูลหลังจากลบแถวที่มีค่า NaN ออกแล้ว ซึ่งควรเท่ากับ 210 − 94 = 116

# %%
rowsCount = df.shape[0]
print("rows count : ", rowsCount)
# Out:
# rows count :  116

# %% [markdown]
# 2.9 ตรวจสอบชนิดของข้อมูลในแต่ละคอลัมน์ ใน Pandas DataFrame

# %%
df.dtypes
# Out:
# Nutrition facts       object
# serving size (g)      object
# Calories             float64
# Calories from fat    float64
# Total fat (g)        float64
# Saturated Fat (g)    float64
# Trans Fat (g)        float64
# Chol (mg)            float64
# Sodium (mg)          float64
# Total Carb (g)        object
# Dietary Fiber (g)    float64
# Total Sugar (g)      float64
# Protein (g)          float64
# dtype: object

# %% [markdown]
# - แปลงข้อมูลในคอลัมน์ serving size (g) และ Total Carb (g) จากชนิด object ไปเป็น float64

# %%
df['serving size (g)'] = df['serving size (g)'].astype(np.float64)
df['Total Carb (g)'] = df['Total Carb (g)'].astype(np.float64)

# %%
df.dtypes
# Out:
# Nutrition facts       object
# serving size (g)     float64
# Calories             float64
# Calories from fat    float64
# Total fat (g)        float64
# Saturated Fat (g)    float64
# Trans Fat (g)        float64
# Chol (mg)            float64
# Sodium (mg)          float64
# Total Carb (g)       float64
# Dietary Fiber (g)    float64
# Total Sugar (g)      float64
# Protein (g)          float64
# dtype: object

# %% [markdown]
# 2.10 แสดงค่าสถิติเชิงพรรณาสําหรับข้อมูลใน DataFrame

# %%
df.describe()
# Out:
#        serving size (g)     Calories  Calories from fat  Total fat (g)  \
# count        116.000000   116.000000         116.000000     116.000000
# mean         155.017241   394.137931         197.672414      21.935345
# std          100.782071   243.742804         148.045867      16.483395
# min           10.000000    10.000000           0.000000       0.000000
# 25%           87.000000   227.500000         100.000000      11.000000
# 50%          135.000000   335.000000         155.000000      17.000000
# 75%          214.500000   510.000000         270.000000      30.000000
# max          464.000000  1190.000000         710.000000      79.000000
#
#        Saturated Fat (g)  Trans Fat (g)   Chol (mg)  Sodium (mg)  \
# count         116.000000     116.000000  116.000000   116.000000
# mean            6.939655       0.379310   66.379310   764.655172
# std             5.962986       0.762207   80.202424   555.232706
# min             0.000000       0.000000    0.000000     0.000000
# 25%             2.875000       0.000000   10.000000   260.000000
# 50%             5.000000       0.000000   32.500000   720.000000
# 75%             9.000000       0.500000  101.250000  1080.000000
# max            31.000000       3.500000  375.000000  2460.000000
#
#        Total Carb (g)  Dietary Fiber (g)  Total Sugar (g)  Protein (g)
# count      116.000000         116.000000       116.000000   116.000000
# mean        34.387931           1.879310         8.870690    15.224138
# std         18.859098           1.784743         8.828344    13.954638
# min          1.000000           0.000000         0.000000     0.000000
# 25%         26.000000           1.000000         2.000000     4.000000
# 50%         31.000000           1.000000         7.000000    12.000000
# 75%         48.000000           2.000000        11.000000    23.250000
# max        123.000000           9.000000        41.000000    61.000000

# %% [markdown]
# 2.11 วาด scatter plot แสดงความสัมพันธ์ระหว่างจํานวน serving size (g) และ Calories

# %%
df.plot.scatter(x='serving size (g)', y='Calories',color='YellowGreen',s=20);

# %% [markdown]
# 2.12 แปลงค่าปริมาณสารอาหาร ให้อยู่ในอัตราส่วนของ serving size (g) ที่เท่ากัน —เนื่องจากปริมาณสารอาหารใน
# อาหารแต่ละชนิด มาจากปริมาณ serving size (g) ที่ต่างกัน ดังนั้น เราควรจะแปลงค่ามันให้เทียบมาจาก ปริมาณ serving size (g) ที่เท่าๆกัน โดยมีหลักคิดคือ —ถ้า ปริมาณ serving size = s, มีปริมาณสารอาหารในคอลัมน์ B = b ดังนั้น ที่ปริมาณ serving size = max_s จะมีปริมาณสารอาหารในคอลัมน์ B = b ∗ max_s/s

# %%
df['serving size (g)'].nlargest(5)
# Out:
# 83    464.0
# 63    395.0
# 9     377.0
# 84    371.0
# 64    369.0
# Name: serving size (g), dtype: float64

# %% [markdown]
# - หาปริมาณ serving size (g) ที่สูงที่สุดในชุดข้อมูล และเก็บไว้ในตัวแปรชื่อ max_ss

# %%
max_ss = max(df['serving size (g)'])
print("MAX Serving Size : ",max_ss)
# Out:
# MAX Serving Size :  464.0

# %% [markdown]
# - แปลงค่าปริมาณสารอาหารในคอลัมน์ต่างๆ โดยเทียบกับ serving size (g) ที่สูงที่สุด

# %%
df
# Out:
#                                Nutrition facts  serving size (g)  Calories  \
# 1                            WHOPPER® Sandwich             270.0     660.0
# 2                                     w/o Mayo             249.0     500.0
# 3                WHOPPER® Sandwich with Cheese             292.0     740.0
# 4                                     w/o Mayo             271.0     580.0
# 5             Bacon & Cheese WHOPPER® Sandwich             303.0     790.0
# 6                  BBQ Bacon WHOPPER® Sandwich             303.0     800.0
# 7                     DOUBLE WHOPPER® Sandwich             354.0     900.0
# 8                                     w/o Mayo             333.0     740.0
# 9         DOUBLE WHOPPER® Sandwich with Cheese             377.0     980.0
# 10                                    w/o Mayo             355.0     820.0
# 11                       WHOPPER JR.® Sandwich             134.0     310.0
# 33        60.0        990.0            48.0                2.0
# ..         ...          ...             ...                ...
# 100        0.0        580.0            24.0                3.0
# 101        0.0       1140.0            48.0                7.0
# 102        0.0       1530.0            65.0                9.0
# 103        0.0        260.0            29.0                1.0
# 104        0.0        430.0            49.0                2.0
# 106        0.0        310.0            51.0                1.0
# 107       10.0        220.0            32.0                1.0
# 108        5.0        200.0            31.0                2.0
# 109        5.0        230.0            36.0                1.0
# 110       20.0        150.0            32.0                0.0
# 111       20.0        150.0            28.0                0.0
# 112       25.0        260.0            53.0                0.0
# 113       20.0        220.0            47.0                1.0
# 114       15.0        135.0            22.0                0.0
# 115       10.0        120.0            22.0                1.0
# 116        5.0        125.0            23.0                0.0
# 117       10.0        135.0            25.0                1.0
# 118       20.0        250.0            47.0                1.0
# 119       20.0        240.0            44.0                0.0
# 120       20.0        260.0            46.0                3.0
# 122       10.0        180.0             1.0                0.0
# 123        0.0        125.0             3.0                0.0
# 124       10.0         75.0             1.0                0.0
# 125        0.0          0.0             7.0                0.0
# 126        0.0         15.0            30.0                0.0
# 127        0.0        310.0            11.0                0.0
# 128       10.0        230.0             1.0                0.0
# 129        5.0        360.0             2.0                0.0
# 130       10.0        180.0             6.0                0.0
# 131       20.0        240.0             3.0                0.0
#
#      Total Sugar (g)  Protein (g)
# 1               11.0         28.0
# 2               11.0         28.0
# 3               11.0         32.0
# 4               11.0         32.0
# 5               11.0         35.0
# 6               14.0         35.0
# 7               11.0         48.0
# 8               11.0         47.0
# 9               11.0         52.0
# 10              11.0         52.0
# 11               7.0         13.0
# 13              10.0         61.0
# 14              10.0         30.0
# 15               6.0         11.0
# 16               7.0         13.0
# 17               6.0         18.0
# 18               7.0         20.0
# 19               9.0         26.0
# 20               7.0         15.0
# 21               7.0         21.0
# 22               7.0         20.0
# 23               7.0         14.0
# 25              10.0         11.0
# 26               5.0         14.0
# 28               7.0         37.0
# 29               7.0         36.0
# 30               8.0         23.0
# 31               7.0         23.0
# 32               5.0         28.0
# 33               4.0         28.0
# ..               ...          ...
# 100              0.0          2.0
# 101              0.0          4.0
# 102              0.0          5.0
# 103              8.0          3.0
# 104             13.0          5.0
# 106             25.0          3.0
# 107             22.0          3.0
# 108             21.0          5.0
# 109             25.0          4.0
# 110             24.0          5.0
# 111             24.0          5.0
# 112             39.0          6.0
# 113             41.0          6.0
# 114             12.0          2.0
# 115             14.0          2.0
# 116             14.0          1.0
# 117             13.0          2.0
# 118             29.0          3.0
# 119             28.0          4.0
# 120             26.0          4.0
# 122              0.0          2.0
# 123              2.0          0.0
# 124              0.0          0.0
# 125              6.0          0.0
# 126             18.0          0.0
# 127             10.0          0.0
# 128              1.0          1.0
# 129              1.0          0.0
# 130              5.0          0.0
# 131              1.0          0.0
#
# [116 rows x 13 columns]

# %%
orig_serving_size = df['serving size (g)'].copy()
df[df.select_dtypes(include=['float64']).columns] = df[df.select_dtypes(include=['float64']).columns]*max_ss
df[df.select_dtypes(include=['float64']).columns].div(orig_serving_size.values, axis='rows')
# Out:
#      serving size (g)     Calories  Calories from fat  Total fat (g)  \
# 1               464.0  1134.222222         618.666667      68.740741
# 2               464.0   931.726908         372.690763      40.995984
# 9         61.538462           2.461538        13.538462    64.000000
# 10        65.352113           2.614085        14.377465    67.966197
# 11        93.492537           3.462687        24.238806    45.014925
# 13        63.865169           2.606742        13.033708    79.505618
# 14       105.056604           4.377358        21.886792    65.660377
# 15       129.720430           4.989247        29.935484    54.881720
# 16       120.461538           4.461538        31.230769    58.000000
# 17        97.290323           3.741935        22.451613    67.354839
# 18        92.800000           3.437037        24.059259    68.740741
# 19        98.028169           4.356808        19.605634    56.638498
# 20       112.864865           4.180180        29.261261    62.702703
# 21        90.129496           3.338129        23.366906    70.100719
# 22        92.800000           3.437037        24.059259    68.740741
# 23        93.467626           3.338129        23.366906    46.733813
# 25       120.715447           7.544715        37.723577    41.495935
# 26       105.626016           7.544715        18.861789    52.813008
# 28        79.021834          12.157205        14.183406    74.969432
# 29        84.560748          13.009346        15.177570    78.056075
# 30       109.894737           4.070175        16.280702    46.807018
# 31       125.280000           4.640000        16.240000    53.360000
# 32       101.698630           4.237443        10.593607    59.324201
# 33       117.221053           4.884211         9.768421    68.378947
# ..              ...                ...              ...          ...
# 100      132.571429          16.571429         0.000000    11.047619
# 101      131.786982          19.218935         0.000000    10.982249
# 102      134.044444          18.560000         0.000000    10.311111
# 103      207.015385           7.138462        57.107692    21.415385
# 104      208.587156           8.513761        55.339450    21.284404
# 106      221.158879           4.336449       108.411215    13.009346
# 107      187.949367           5.873418       129.215190    17.620253
# 108      205.485714          13.257143       139.200000    33.142857
# 109      206.222222           5.728395       143.209877    22.913580
# 110      123.733333           0.000000        92.800000    19.333333
# 111      112.973913           0.000000        96.834783    20.173913
# 112      160.732026           0.000000       118.274510    18.196078
# 113      148.353741           3.156463       129.414966    18.938776
# 114      283.555556           0.000000       154.666667    25.777778
# 115      283.555556          12.888889       180.444444    25.777778
# 116      296.444444           0.000000       180.444444    12.888889
# 117      305.263158          12.210526       158.736842    24.421053
# 118      286.947368           6.105263       177.052632    18.315789
# 119      268.631579           0.000000       170.947368    24.421053
# 120      280.842105          18.315789       158.736842    24.421053
# 122       42.181818           0.000000         0.000000    84.363636
# 123      139.200000           0.000000        92.800000     0.000000
# 124       38.666667           0.000000         0.000000     0.000000
# 125      270.666667           0.000000       232.000000     0.000000
# 126      339.512195           0.000000       203.707317     0.000000
# 127      182.285714           0.000000       165.714286     0.000000
# 128       16.571429           0.000000        16.571429    16.571429
# 129       33.142857           0.000000        16.571429     0.000000
# 130       99.428571           0.000000        82.857143     0.000000
# 131       49.714286           0.000000        16.571429     0.000000
#
# [116 rows x 12 columns]

# %% [markdown]
# 2.13 ตรวจดูว่าาข้อมูลมีค่าที่ต่ำหรือสูงผิดปกติ (outliers) หรือไม่

# %% [markdown]
# วาด boxplot สําหรับข้อมูลทุกคอลัมน์ ยกเว้นคอลัมน์แรกที่ไม่ใช่ข้อมูลตัวเลข โดยให้ boxplots ทุกอันอยู่ใน figure และ plot เดียวกัน

# %%
color = dict(boxes='DarkGreen', whiskers='DarkOrange',medians='DarkBlue', caps='Gray')
fig, ax = plt.subplots()
df.plot.box(color=color,ax=ax,figsize=(15, 10),sym='ro')
fig.tight_layout()
fig.autofmt_xdate()
