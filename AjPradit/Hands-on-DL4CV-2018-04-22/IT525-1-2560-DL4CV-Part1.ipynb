# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
cv2.__version__
# Out:
# '3.4.1'

# %%
# Accessing and Modifying pixel values
# load a color image first
img = cv2.imread('messi5.jpg', cv2.IMREAD_COLOR )
img2=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img[...,::-1])

# %%
plt.imshow(img2)

# %%
cv2.imshow('image1',img)

# %%
# access a pixel value by its row and column coordinates
px = img[100,100]   # Show [157 166 200]
print(px) 

# accessing only blue pixel
blue = img[100,100,0]
print(blue) # Show 157 166 200

#  modify the pixel values the same way.
img[100,100] = [255,255,255]
print( img[100,100] ) # Show [255 255 255]

# Accessing Image Properties
print(img.shape) # number of rows, columns and channels (if color)
print(img.size) # Total number of pixels 
print(img.dtype) # Image datatype

# Image ROI
ball=img[280:340,330:390]
img[273:333,100:160]=ball
#cv2.imshow('image2',img)
#cv2.waitKey(0)
#cv2.destroyAllWindows()

plt.imshow(img[...,::-1])

# splitting and Merging Image Channels
b,g,r = cv2.split(img)
img = cv2.merge((b,g,r))
b = img[:,:,0]
img[:,:,2] = 0
# Out:
# ---------------------------------------------------------------------
# NameError                           Traceback (most recent call last)
# <ipython-input-15-bf928d8e9051> in <module>()
#       1
#       2 # access a pixel value by its row and column coordinates
# ----> 3 px = img[100,100]   # Show [157 166 200]
#       4 print(px)
#       5
#
# NameError: name 'img' is not defined

# %%
from skimage import io
from scipy.misc import imread, imsave, imresize
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

im1 = io.imread("messi5.jpg")
im2=np.zeros(im1.shape,im1.dtype)
im2[:,:,0] = im1[:,:,2]
im2[:,:,1] = im1[:,:,1]
im2[:,:,2] = im1[:,:,0]

plt.imshow(im2)

io.imsave("messi5_bgr.jpg",im2)
